# %%
from __future__ import annotations
from typing import TYPE_CHECKING, Any

if TYPE_CHECKING:
    from typing_extensions import Self
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import numpy.typing as npt


class PerformancePlot:
    def __init__(self, dpi: int, figsize: tuple[int, int]) -> None:
        self.fig = plt.figure(figsize=figsize, dpi=dpi)
        self.ax = plt.subplot()

    def plot(
        self,
        color: str,
        x_label: str,
        y_label: str,
        x_ticks: list[str],
        Y: npt.NDArray[np.float64 | np.int64],
        X: npt.NDArray[np.float64 | np.int64] | None = None,
        y_max: int = 500,
    ) -> Self:
        X = X or np.arange(len(Y))

        rects = self.ax.bar(X, Y, width=0.3, color=color)
        self.ax.bar_label(rects, padding=3)

        self.ax.xaxis.set_ticks(X.tolist(), x_ticks, fontsize=12, family="serif")
        self.ax.set_ylabel(y_label, labelpad=10.0, fontsize=12, family="serif")
        self.ax.set_xlabel(x_label, labelpad=10.0, fontsize=12, family="serif")

        self.ax.grid(alpha=0.5, axis="y")
        self.fig.tight_layout()
        self.fig.subplots_adjust(right=0.92)

        self.ax.set_ylim(0, y_max)

        return self

# %%
PLOT_SHAPE = (9, 5)
DPI = 300

# %% [markdown]
# # Wstępne pomiary wydajności - LOCKED

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "dodgerblue",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                36.630,
                36.757,
                35.986,
                36.458,
                37.012,
            ],
            [  # 4
                6.060,
                6.008,
                6.014,
                5.991,
                5.969,
            ],
            [  # 8
                9.994,
                10.325,
                10.370,
                9.951,
                10.239,
            ],
            [  # 16
                17.214,
                17.032,
                17.315,
                17.112,
                17.344,
            ],
            [  # 32
                45.787,
                46.599,
                45.977,
                46.198,
                46.309,
            ],  # 64
            [
                270.353,
                271.186,
                273.862,
                272.992,
                274.223,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("original_performance_tests_locked.png")

# %% [markdown]
# # Wstępne pomiary wydajności - UNLOCKED

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "coral",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                36.545,
                35.768,
                36.456,
                36.895,
                36.346,
            ],
            [
                6.115,
                6.055,
                6.080,
                6.095,
                6.057,
            ],
            [
                10.207,
                10.198,
                10.292,
                10.068,
                10.360,
            ],
            [
                17.358,
                17.778,
                17.168,
                17.341,
                17.479,
            ],
            [  # 32
                45.787,
                46.599,
                45.977,
                46.198,
                46.309,
            ],  # 64
            [
                404.346,
                399.866,
                411.107,
                400.706,
                404.031,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("original_performance_tests.png")

# %% [markdown]
# # Python i NumPy

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "seagreen",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                28.834342,
                28.608548,
                28.469984,
                28.517128,
                28.844327,
            ],
            [
                6.497375,
                6.430537,
                6.446660,
                6.415676,
                6.515660,
            ],
            [
                10.107058,
                10.410428,
                10.152248,
                10.278387,
                10.36032,
            ],
            [
                15.410092,
                15.280992,
                15.341320,
                15.772114,
                15.479850,
            ],
            [  # 32
                33.808527,
                33.351207,
                33.180048,
                33.538432,
                33.525192,
            ],  # 64
            [
                198.197667,
                198.495232,
                198.561772,
                199.254051,
                199.530102,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("python_and_numpy_performance_tests.png")

# SINGLE PRECISION

PerformancePlot(DPI, PLOT_SHAPE).plot(
    "mediumseagreen",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                24.913664,
                24.781220,
                24.764553,
                24.566121,
                25.222701,
            ],
            [
                6.496272,
                6.383893,
                6.327793,
                6.244867,
                6.345666,
            ],
            [
                10.336874,
                10.148280,
                10.010672,
                10.290808,
                10.039265,
            ],
            [
                15.086650,
                15.111621,
                14.967826,
                15.150140,
                15.113235,
            ],
            [  # 32
                29.475359,
                29.406027,
                29.895123,
                29.543779,
                29.145641,
            ],  # 64
            [
                144.601767,
                144.381824,
                143.268733,
                145.057398,
                144.874395,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("python_and_numpy_single_tests.png")

# %% [markdown]
# # Python i NumPy z AOT

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "goldenrod",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                28.288767,
                28.447683,
                28.515472,
                28.066156,
                28.268619,
            ],
            [  # 4
                6.392602,
                6.223264,
                6.315662,
                6.075753,
                6.969,
            ],
            [  # 8
                10.007133,
                10.048594,
                10.145933,
                10.147876,
                10.885933,
            ],
            [  # 16
                15.302059,
                15.253169,
                15.082352,
                15.569242,
                15.324344,
            ],
            [  # 32
                33.332312,
                33.508812,
                33.676550,
                33.990577,
                33.306769,
            ],  # 64
            [
                197.972171,
                197.690525,
                194.104837,
                197.236684,
                196.366223,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("python_and_numpy_and_aot_performance_tests.png")

PerformancePlot(DPI, PLOT_SHAPE).plot(
    "gold",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                24.221301,
                23.982814,
                24.432785,
                24.672234,
                24.346565,
            ],
            [  # 4
                6.313473,
                6.273513,
                6.341342,
                6.220932,
                6.634345,
            ],
            [  # 8
                9.986561,
                9.870561,
                10.063751,
                10.025111,
                10.123432,
            ],
            [  # 16
                14.497029,
                15.037487,
                15.168283,
                15.028384,
                15.014254,
            ],
            [  # 32
                28.575323,
                29.083435,
                29.041272,
                28.889320,
                28.745634,
            ],  # 64
            [
                141.717631,
                140.732149,
                139.470392,
                141.418889,
                142.653545,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("python_and_numpy_and_aot_single_tests.png")

# %% [markdown]
# # Python i NumPy z JIT

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "deepskyblue",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                25.616753,
                21.345537,
                21.944291,
                21.719802,
                22.211492,
            ],
            [  # 4
                3.905430,
                3.814764,
                3.751026,
                3.795585,
                3.969435,
            ],
            [  # 8
                5.882402,
                6.151603,
                6.093301,
                6.045042,
                7.543234,
            ],
            [  # 16
                8.915260,
                8.825061,
                9.000120,
                8.870948,
                8.724344,
            ],
            [  # 32
                18.024615,
                18.236297,
                17.997644,
                18.508492,
                18.406269,
            ],  # 64
            [
                93.093818,
                91.887223,
                92.413379,
                94.335950,
                93.879579,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("python_and_numpy_and_jit_performance_tests.png")

PerformancePlot(DPI, PLOT_SHAPE).plot(
    "skyblue",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                18.456345,
                17.582523,
                18.281202,
                17.679599,
                17.347749,
            ],
            [  # 4
                7.361692,
                3.826850,
                3.795692,
                4.636122,
                3.465744,
            ],
            [  # 8
                5.942802,
                6.093372,
                5.845786,
                5.836591,
                5.457577,
            ],
            [  # 16
                9.066243,
                9.254037,
                8.943389,
                9.008097,
                9.032145,
            ],
            [  # 32
                18.212309,
                17.925048,
                18.127972,
                18.210678,
                18.745654,
            ],  # 64
            [
                95.851051,
                94.429204,
                95.223052,
                94.187464,
                93.678933,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("python_and_numpy_and_jit_single_tests.png")

# %% [markdown]
# # Rust + Ndaray

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "firebrick",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                40.025642,
                64.702314,
                44.944552,
                44.822482,
                47.870028,
            ],
            [  # 4
                1.251262,
                0.983796,
                1.013157,
                1.111524,
                1.183622,
            ],
            [  # 8
                2.160503,
                2.092576,
                1.973408,
                1.812471,
                2.025353,
            ],
            [  # 16
                8.879180,
                9.276569,
                6.493606,
                9.497257,
                7.457745,
            ],
            [  # 32
                51.285207,
                68.454821,
                42.279841,
                49.234672,
                53.646346,
            ],  # 64
            [
                455.609348,
                402.772052,
                470.480689,
                504.991994,
                434.423640,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("rust_performance_tests.png")

PerformancePlot(DPI, PLOT_SHAPE).plot(
    "salmon",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                25.711258,
                24.212482,
                27.688681,
                22.790833,
                25.706462,
            ],
            [  # 4
                0.465780,
                0.501815,
                0.477064,
                0.455157,
                0.462883,
            ],
            [  # 8
                0.906756,
                0.812369,
                0.862826,
                0.877215,
                0.852042,
            ],
            [  # 16
                3.870183,
                4.174736,
                3.975512,
                4.178935,
                3.934112,
            ],
            [  # 32
                28.696387,
                29.163355,
                29.519621,
                28.832970,
                30.633616,
            ],  # 64
            [
                249.526633,
                239.694042,
                236.964745,
                237.638968,
                234.928612,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("rust_single_tests.png")

# %% [markdown]
# # Rust + Ndaray + OpenBLAS

# %%
PerformancePlot(DPI, PLOT_SHAPE).plot(
    "purple",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                21.710550,
                21.794771,
                18.001041,
                20.108443,
                21.133621,
            ],
            [  # 4
                1.051102,
                1.038687,
                1.291347,
                0.886877,
                1.040473,
            ],
            [  # 8
                1.506531,
                1.421974,
                1.476399,
                1.205314,
                1.540289,
            ],
            [  # 16
                4.541902,
                5.155594,
                4.817381,
                5.208212,
                5.159769,
            ],
            [  # 32
                28.946964,
                24.932343,
                20.061114,
                22.969836,
                23.355491,
            ],  # 64
            [
                215.413583,
                211.147161,
                187.453838,
                202.887633,
                189.946526,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("rust_blas_perf_tests.png")

PerformancePlot(DPI, PLOT_SHAPE).plot(
    "fuchsia",
    "Macierz wejściowa",
    "Czas [s]",
    [
        "32\xD732\n$\\rho_1$",
        "4\xD74\n$\\rho_2$",
        "8\xD78\n$\\rho_3$",
        "16\xD716\n$\\rho_4$",
        "32\xD732\n$\\rho_5$",
        "64\xD764\n$\\rho_6$",
    ],
    np.array(
        [
            [
                6.519945,
                6.079472,
                5.974087,
                6.780244,
                6.144553,
            ],
            [  # 4
                0.480443,
                0.500618,
                0.656021,
                0.562958,
                0.567673,
            ],
            [  # 8
                0.560129,
                0.601810,
                0.618427,
                0.530310,
                0.675051,
            ],
            [  # 16
                1.478650,
                1.622910,
                1.475271,
                1.510523,
                1.453896,
            ],
            [  # 32
                7.149567,
                7.760586,
                6.622034,
                6.995596,
                7.438749,
            ],  # 64
            [
                58.138993,
                52.094275,
                54.026881,
                53.987907,
                55.848131,
            ],
        ]
    )
    .mean(axis=1)
    .round(1),
).fig.savefig("rust_blas_single_tests.png")

# %%
class Column:
    def __init__(self, name: str, color: str, value: float) -> None:
        self.name = name
        self.color = color
        self.value = value


class MatrixPlot:
    def __init__(self, dpi: int, figsize: tuple[int, int]) -> None:
        self.fig = plt.figure(figsize=figsize, dpi=dpi)
        self.ax = plt.subplot()

    def plot(
        self,
        columns: list[Column],
        x_label: str,
        y_lim: int | float,
        x_tick_density: int | float = 1,
    ) -> Self:
        Y = []
        ticks = []

        for i, col in enumerate(columns):
            Y.append(i)
            ticks.append(col.name)
            rects = self.ax.barh(i, col.value, color=col.color, height=0.7)
            self.ax.bar_label(rects, padding=3)

        self.ax.yaxis.set_ticks(Y, ticks, fontsize=12, family="serif")

        X = np.arange(0, y_lim, x_tick_density)
        self.ax.xaxis.set_ticks(X, X, fontsize=12, family="serif")

        self.ax.set_xlabel(x_label, labelpad=10.0, fontsize=12, family="serif")

        self.ax.grid(alpha=0.5, axis="x")
        self.fig.tight_layout()
        self.fig.subplots_adjust(right=0.92)

        self.ax.set_xlim(0, y_lim)

        return self

# %%
PLOT_SHAPE_MTX_PLOT = (12, 6)

# %%
MatrixPlot(DPI, PLOT_SHAPE_MTX_PLOT).plot(
    list(
        reversed(
            [
                Column("Oryginał", "coral", 36.4),
                Column("Oryginał (zablokowany)", "dodgerblue", 36.6),
                Column("Python i NumPy (F64)", "seagreen", 28.7),
                Column("Python i NumPy (F32)", "mediumseagreen", 24.8),
                Column("Python i NumPy z AOT (F64)", "goldenrod", 28.3),
                Column("Python i NumPy z AOT (F32)", "gold", 24.3),
                Column("Python i NumPy z JIT (F64)", "deepskyblue", 22.6),
                Column("Python i NumPy z JIT (F32)", "skyblue", 17.9),
                Column("Rust i Ndarray (F64)", "firebrick", 48.5),
                Column("Rust i Ndarray (F32)", "salmon", 25.2),
                Column("Rust i Ndarray z OpenBLAS (F64)", "purple", 48.5),
                Column("Rust i Ndarray z OpenBLAS (F32)", "fuchsia", 25.2),
            ]
        )
    ),
    "Czas [s]",
    60,
    x_tick_density=4,
).fig.savefig("rho_1_matrix_comparison.png")

# %%
MatrixPlot(DPI, PLOT_SHAPE_MTX_PLOT).plot(
    list(
        reversed(
            [
                Column("Oryginał", "coral", 6.1),
                Column("Oryginał (zablokowany)", "dodgerblue", 6),
                Column("Python i NumPy (F64)", "seagreen", 6.5),
                Column("Python i NumPy (F32)", "mediumseagreen", 6.4),
                Column("Python i NumPy z AOT (F64)", "goldenrod", 6.4),
                Column("Python i NumPy z AOT (F32)", "gold", 6.4),
                Column("Python i NumPy z JIT (F64)", "deepskyblue", 3.8),
                Column("Python i NumPy z JIT (F32)", "skyblue", 4.6),
                Column("Rust i Ndarray (F64)", "firebrick", 1.1),
                Column("Rust i Ndarray (F32)", "salmon", 0.5),
                Column("Rust i Ndarray z OpenBLAS (F64)", "purple", 1.1),
                Column("Rust i Ndarray z OpenBLAS (F32)", "fuchsia", 0.6),
            ]
        )
    ),
    "Czas [s]",
    10.01,
    x_tick_density=1,
).fig.savefig("rho_2_matrix_comparison.png")

# %%
MatrixPlot(DPI, PLOT_SHAPE_MTX_PLOT).plot(
    list(
        reversed(
            [
                Column("Oryginał", "coral", 10.2),
                Column("Oryginał (zablokowany)", "dodgerblue", 10.2),
                Column("Python i NumPy (F64)", "seagreen", 10.3),
                Column("Python i NumPy (F32)", "mediumseagreen", 10.2),
                Column("Python i NumPy z AOT (F64)", "goldenrod", 10.2),
                Column("Python i NumPy z AOT (F32)", "gold", 10),
                Column("Python i NumPy z JIT (F64)", "deepskyblue", 6.3),
                Column("Python i NumPy z JIT (F32)", "skyblue", 5.8),
                Column("Rust i Ndarray (F64)", "firebrick", 2),
                Column("Rust i Ndarray (F32)", "salmon", 0.9),
                Column("Rust i Ndarray z OpenBLAS (F64)", "purple", 1.4),
                Column("Rust i Ndarray z OpenBLAS (F32)", "fuchsia", 0.6),
            ]
        )
    ),
    "Czas [s]",
    13.01,
    x_tick_density=1,
).fig.savefig("rho_3_matrix_comparison.png")

# %%
MatrixPlot(DPI, PLOT_SHAPE_MTX_PLOT).plot(
    list(
        reversed(
            [
                Column("Oryginał", "coral", 17.4),
                Column("Oryginał (zablokowany)", "dodgerblue", 17.2),
                Column("Python i NumPy (F64)", "seagreen", 15.5),
                Column("Python i NumPy (F32)", "mediumseagreen", 15.1),
                Column("Python i NumPy z AOT (F64)", "goldenrod", 15.3),
                Column("Python i NumPy z AOT (F32)", "gold", 14.9),
                Column("Python i NumPy z JIT (F64)", "deepskyblue", 8.9),
                Column("Python i NumPy z JIT (F32)", "skyblue", 9.1),
                Column("Rust i Ndarray (F64)", "firebrick", 8.3),
                Column("Rust i Ndarray (F32)", "salmon", 4),
                Column("Rust i Ndarray z OpenBLAS (F64)", "purple", 5),
                Column("Rust i Ndarray z OpenBLAS (F32)", "fuchsia", 1.5),
            ]
        )
    ),
    "Czas [s]",
    22.01,
    x_tick_density=2,
).fig.savefig("rho_4_matrix_comparison.png")

# %%
MatrixPlot(DPI, PLOT_SHAPE_MTX_PLOT).plot(
    list(
        reversed(
            [
                Column("Oryginał", "coral", 46.2),
                Column("Oryginał (zablokowany)", "dodgerblue", 46.2),
                Column("Python i NumPy (F64)", "seagreen", 33.5),
                Column("Python i NumPy (F32)", "mediumseagreen", 29.5),
                Column("Python i NumPy z AOT (F64)", "goldenrod", 33.6),
                Column("Python i NumPy z AOT (F32)", "gold", 28.9),
                Column("Python i NumPy z JIT (F64)", "deepskyblue", 18.2),
                Column("Python i NumPy z JIT (F32)", "skyblue", 18.2),
                Column("Rust i Ndarray (F64)", "firebrick", 53),
                Column("Rust i Ndarray (F32)", "salmon", 29.4),
                Column("Rust i Ndarray z OpenBLAS (F64)", "purple", 24.1),
                Column("Rust i Ndarray z OpenBLAS (F32)", "fuchsia", 7.2),
            ]
        )
    ),
    "Czas [s]",
    60.01,
    x_tick_density=4,
).fig.savefig("rho_5_matrix_comparison.png")

# %%
MatrixPlot(DPI, PLOT_SHAPE_MTX_PLOT).plot(
    list(
        reversed(
            [
                Column("Oryginał", "coral", 404),
                Column("Oryginał (zablokowany)", "dodgerblue", 272.5),
                Column("Python i NumPy (F64)", "seagreen", 198.8),
                Column("Python i NumPy (F32)", "mediumseagreen", 144.4),
                Column("Python i NumPy z AOT (F64)", "goldenrod", 196.7),
                Column("Python i NumPy z AOT (F32)", "gold", 141.2),
                Column("Python i NumPy z JIT (F64)", "deepskyblue", 93.1),
                Column("Python i NumPy z JIT (F32)", "skyblue", 94.7),
                Column("Rust i Ndarray (F64)", "firebrick", 453.7),
                Column("Rust i Ndarray (F32)", "salmon", 239.8),
                Column("Rust i Ndarray z OpenBLAS (F64)", "purple", 201.4),
                Column("Rust i Ndarray z OpenBLAS (F32)", "fuchsia", 54.8),
            ]
        )
    ),
    "Czas [s]",
    500.01,
    x_tick_density=50,
).fig.savefig("rho_6_matrix_comparison.png")
